# %% [markdown]
# # Assignment 1:

# %% [markdown]
# ##### 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# *
# 'hello'
# -87.8
# -
# /
# +
# 6

# %% [markdown]
# ###### Solution:
#
# 'hello' : Value (string)
#
# 87.8 : value(float)
#
# / : expression
#
# 6 : Value (integer)

# %% [markdown]
# ##### 2. What is the difference between string and variable?

# %% [markdown]
# ##### Solution:
#
# Variable is used to store values/information into it so that it becomes easy to access that information whereas,
# string is a type of information you would store in a variable.
#
# Eg: name(this is a variable) = 'My name is ..' (this is string which is being store in name varibale.

# %% [markdown]
# ##### 3. Describe three different data types.

# %% [markdown]
# ##### Solution:
#
# The three data types are:
#
# 1. Numeric Type : It signifies all the integer,float(decimal) and complex values in python.
#
# 2. Text type : str represents all the text type information.
#
# 3. Sequence type : It represents all the data types which include list, tuple. List are set of data type which can store multiple varied values/items in a single variable. Tuples also allows to sore multiple varied values/items in a single variable with one exception that tuple is immutable.

# %% [markdown]
# ##### 4. What is an expression made up of? What do all expressions do?

# %% [markdown]
# ##### Solution:
#
# Expression is a combination of operators that is interpreted to produce other value.
# Expressions helps to evaluate different values/items and produce new result.

# %% [markdown]
# ##### 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# ##### Solution:
#
# A statement in Python is used for creating variables or for displaying values. The expression in Python produces some value or result after being interpreted by the Python interpreter.

# %% [markdown]
# ##### 6. After running the following code, what does the variable bacon contain?
# bacon = 22
#
# bacon + 1

# %% [markdown]
# ##### Solution:
#
# Bacon will contain 22 as value since while adding 1 to bacon we have not yet assigned again to the variable 'bacon'.
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 7. What should the values of the following two terms be?
#
# 'spam' + 'spamspam'
#
# 'spam' * 3

# %% [markdown]
# ##### Solution:
#
# The result will be 'spamspamspam' for both the expression:
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# ##### Solution :
#
# While naming variables in python few rules have to be followed so that the code does not run into error. Hence, use of digit to begin a variable makes error checking during compilation a lot more complicated.

# %% [markdown]
# ##### 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [markdown]
# ##### Solution:
#
# The three functions are:
#
# 1. int() to get integer value
# 2. float() to get floating -point number value
# 3. str() to get string version of value

# %% [markdown]
# ###### 10. Why does this expression cause an error? How can you fix it?
#
# 'I have eaten ' + 99 + ' burritos.

# %% [markdown]
# ###### Solution:
#
# This failure occurs because the concatenate operator (+) for strings in Python doesn't know how to convert numeric types to strings. So in order to resolve this issue we can convert integer value to string value or use ',' instead of '+' while printing the expression.
